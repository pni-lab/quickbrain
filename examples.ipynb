# %% [markdown]
# # quickbrain — examples
#
# **quickbrain** provides fast, lightweight whole-brain surface plotting with a single function call.
# Unlike most neuroimaging visualisation packages, the built-in MNI152 meshes include the
# **cerebellum and brainstem**, giving you a complete overview of brain-wide statistical maps.
#
# ```python
# from quickbrain import plot_brain
# ```
#
# That's the only import you need.

# %%
from quickbrain import plot_brain

# %% [markdown]
# ## 1. Quickstart
#
# With no arguments, `plot_brain()` renders the left pial surface with a
# signed-curvature background — gyri and sulci are immediately visible.
# The mesh covers the full hemisphere **including the cerebellum**.

# %%
import nibabel as nib
pain_response = nib.load("resources/placebo_metaanalysis_full_pain_g_random.nii.gz")

# %%
plot_brain(pain_response, surf_type='inflated', threshold=0.0, view='lateral', hemi='left', res=10,
#overlay=None,
)

# %%
import matplotlib.pyplot as plt

_threshold = 0.3    
fig, ax = plt.subplots(1, 4, figsize=(12,10), subplot_kw={"projection": "3d"})
plot_brain(pain_response, hemi='left', view='lateral', threshold=_threshold, axes=ax[0], colorbar=False, title="Left lateral")
plot_brain(pain_response, hemi='left', view='medial', threshold=_threshold, axes=ax[1], colorbar=False, title="Left medial" )
plot_brain(pain_response, hemi='right', view='lateral', threshold=_threshold, axes=ax[2], colorbar=False, title="Right lateral")
plot_brain(pain_response, hemi='right', view='medial', threshold=_threshold, axes=ax[3], colorbar=False, title="Right medial")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/rc/b4064_3d4dj60wt9y_447fyr0000gn/T/ipykernel_57832/210932846.py:9: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt

_threshold = 0.5    
fig, ax = plt.subplots(1, 4, figsize=(12,10), subplot_kw={"projection": "3d"})
plot_brain(pain_response, hemi='left', view='lateral', threshold=_threshold, axes=ax[0], cmap='blue_red', colorbar=False, bg_map=0.01, title="Left lateral")
plot_brain(pain_response, hemi='left', view='medial', threshold=_threshold, axes=ax[1], cmap='blue_red', colorbar=False,  bg_map=0.01, title="Left medial" )
plot_brain(pain_response, hemi='right', view='lateral', threshold=_threshold, axes=ax[2], cmap='blue_red', colorbar=False, bg_map=0.01, title="Right lateral")
plot_brain(pain_response, hemi='right', view='medial', threshold=_threshold, axes=ax[3], cmap='blue_red', colorbar=False, bg_map=0.01, title="Right medial")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/rc/b4064_3d4dj60wt9y_447fyr0000gn/T/ipykernel_55845/4048287829.py:9: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt

_threshold = 0    
fig, ax = plt.subplots(1, 4, figsize=(12,10), subplot_kw={"projection": "3d"})
plot_brain(pain_response, hemi='left', view='lateral', threshold=_threshold, axes=ax[0], colorbar=False, title="Left lateral")
plot_brain(pain_response, hemi='left', view='medial', threshold=_threshold, axes=ax[1], colorbar=False, title="Left medial" )
plot_brain(pain_response, hemi='right', view='lateral', threshold=_threshold, axes=ax[2], colorbar=False, title="Right lateral")
plot_brain(pain_response, hemi='right', view='medial', threshold=_threshold, axes=ax[3], colorbar=False, title="Right medial")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/rc/b4064_3d4dj60wt9y_447fyr0000gn/T/ipykernel_55845/2583883088.py:9: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
hip = nib.load("resources/harvardoxford-subcortical_prob_Left Hippocampus.nii.gz")

plot_brain(hip, view='medial', threshold=30, cmap='viridis')

# %%
import matplotlib.pyplot as plt

_threshold = 0.3    
fig, ax = plt.subplots(1, 4, figsize=(12,10), subplot_kw={"projection": "3d"})
plot_brain(pain_response, hemi='left', view='lateral', surf_type='inflated', threshold=_threshold, axes=ax[0], colorbar=False, title="Left lateral")
plot_brain(pain_response, hemi='left', view='medial', surf_type='inflated', threshold=_threshold, axes=ax[1], colorbar=False, title="Left medial" )
plot_brain(pain_response, hemi='right', view='lateral', surf_type='inflated', threshold=_threshold, axes=ax[2], colorbar=False, title="Right lateral")
plot_brain(pain_response, hemi='right', view='medial', surf_type='inflated', threshold=_threshold, axes=ax[3], colorbar=False, title="Right medial")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/rc/b4064_3d4dj60wt9y_447fyr0000gn/T/ipykernel_55845/772067111.py:9: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt

_threshold = 0.3    
fig, ax = plt.subplots(1, 4, figsize=(12,10), subplot_kw={"projection": "3d"})
plot_brain(pain_response, hemi='left', view='lateral', surf_type='inflated', threshold=_threshold, axes=ax[0], bg_map=0.5, colorbar=False, title="Left lateral", cmap='blue_red')
plot_brain(pain_response, hemi='left', view='medial', surf_type='inflated', threshold=_threshold, axes=ax[1], bg_map=0.5, colorbar=False, title="Left medial", cmap='blue_red' )
plot_brain(pain_response, hemi='right', view='lateral', surf_type='inflated', threshold=_threshold, axes=ax[2], bg_map=0.5, colorbar=False, title="Right lateral", cmap='blue_red')
plot_brain(pain_response, hemi='right', view='medial', surf_type='inflated', threshold=_threshold, axes=ax[3], bg_map=0.5, colorbar=False, title="Right medial", cmap='blue_red')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/rc/b4064_3d4dj60wt9y_447fyr0000gn/T/ipykernel_55845/3675095081.py:9: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
hip = nib.load("resources/harvardoxford-subcortical_prob_Left Hippocampus.nii.gz")

plot_brain(hip, view='medial', threshold=30, cmap='viridis', surf_type='inflated')

# %% [markdown]
# ## 3. Plotting a NIfTI volume
#
# Pass any NIfTI path (or a loaded nibabel image) as `stat_map`.
# quickbrain projects the volume onto the surface automatically via
# `nilearn.surface.vol_to_surf`.
#
# Here we use the Pain-activation stat map bundled with nilearn.

# %%
from matplotlib import pyplot as plt


fig, axes = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={"projection": "3d"})


plot_brain(pain_response,
           threshold=0, 
           res=10,
           title="Pain response (Hedges' g)",
           post_blur=3,
           background="transparent",
           vol_to_surf_radius=3,
           overlay_linewidth=1,
           colorbar=False,
           cmap='coolwarm', #"cold_hot",
           axes=axes[0],
           vmin=-0.5,
           vmax=0.5,
           );

plot_brain(pain_response,
           threshold=0, 
           res=1,
           title="Pain response (Hedges' g)",
           post_blur=3,
           background="transparent",
           vol_to_surf_radius=3,
           overlay_linewidth=1,
           colorbar=False,
           cmap='coolwarm', #"cold_hot",
           axes=axes[1],
           vmin=-0.5,
           vmax=0.5,
           );

# %% [markdown]
# ## 5. Resolution levels
#
# The package ships **two** mesh resolutions: voxel size **10** (`res=10` or `res="low"`) for fast previews, and voxel size **1** (`res=1` or `res="high"`) for a fine mesh. The default is `"low"` (same as `10`).

# %% [markdown]
# ## 7. Background options
#
# The `bg_map` parameter controls the underlay:
#
# | value | effect |
# |---|---|
# | `"curvature"` (default) | signed curvature — highlights gyri/sulci |
# | a float, e.g. `0.5` | uniform grey |
# | `None` | no background (white) |

# %%
fig, (ax1, ax2, ax3) = plt.subplots(
    1, 3,
    figsize=(15, 5),
    subplot_kw={"projection": "3d"},
)

for ax, bg, label in [
    (ax1, "curvature", 'bg_map="curvature"'),
    (ax2, 0.5, "bg_map=0.5"),
    (ax3, 0.1, "bg_map=None"),
]:
    plot_brain(
        pain_response,
        bg_map=bg,
        threshold=0.5,
        axes=ax,
        colorbar=False,
        title=label,
        overlay=None,
    )

plt.tight_layout()
plt.show()
# Out:
# /var/folders/rc/b4064_3d4dj60wt9y_447fyr0000gn/T/ipykernel_55845/2198722074.py:22: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## 10. Saving to file
#
# Use `output_file` to write the figure directly (any format matplotlib
# supports: png, pdf, svg, ...).

# %%
plot_brain(
    pain_response,
    threshold=0.5,
    hemi="right",
    view="medial",
    title="Right medial",
    output_file="/tmp/quickbrain_demo.png",
    overlay=None,
)
print("Saved to /tmp/quickbrain_demo.png")
# Out:
# Saved to /tmp/quickbrain_demo.png

# %% [markdown]
# ## 11. Full four-panel overview
#
# A common use-case: show both hemispheres in lateral and medial views
# in a single figure.  Four lines of `plot_brain` and a shared
# `suptitle` — that's it.

# %%
fig, axes = plt.subplots(
    2, 2,
    figsize=(12, 10),
    subplot_kw={"projection": "3d"},
)

for i, hemi in enumerate(["left", "right"]):
    for j, view in enumerate(["lateral", "medial"]):
        plot_brain(
            pain_response,
            hemi=hemi,
            view=view,
            threshold=0.5,
            axes=axes[i, j],
            colorbar=(j == 1)
        )

fig.suptitle(
    "Pain activation — full overview (incl. cerebellum)",
    fontsize=14,
    y=1.01,
)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/rc/b4064_3d4dj60wt9y_447fyr0000gn/T/ipykernel_55845/941128759.py:23: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## 13. Post-processing blur
#
# `post_blur` (default 3 px) applies a light Gaussian blur to the brain
# rendering *before* the SVG overlay is composited.  This softens the
# polygon edges.  Set to `0` to disable.

# %% [markdown]
# ## 14. Background: white vs. transparent
#
# `background="transparent"` turns the white canvas transparent (useful for
# compositing into posters or slides).  Only two values are allowed:
# `"white"` (default) and `"transparent"`.

# %% [markdown]
# ## 15. Overlay line width
#
# `overlay_linewidth` is a multiplier for the SVG stroke widths.
# Use values > 1 for thicker contours, < 1 for thinner ones.

# %%
plot_brain(pain_response,
           threshold=1, 
           res=1,
           hemi='left',
           view='lateral',
           surf_type='inflated',
           title="Pain response (Hedges' g)",
           post_blur=3,
           background="transparent",
           vol_to_surf_radius=3,
           overlay_linewidth=1,
           colorbar=False,
           cmap='coolwarm', #"cold_hot",
           vmin=-0.5,
           vmax=0.5,
           )

# %%
plot_brain(pain_response,
           threshold=1, 
           res=10,
           hemi='left',
           view='lateral',
           surf_type='inflated',
           title="Pain response (Hedges' g)",
           post_blur=3,
           background="transparent",
           vol_to_surf_radius=3,
           overlay_linewidth=1,
           colorbar=False,
           #overlay=True,
           cmap='coolwarm', #"cold_hot",
           vmin=-0.5,
           vmax=0.5,
           )

# %%
plot_brain(pain_response,
           threshold=1, 
           res=10,
           hemi='left',
           view='lateral',
           surf_type='pial',
           title="Pain response (Hedges' g)",
           post_blur=3,
           background="transparent",
           vol_to_surf_radius=3,
           overlay_linewidth=1,
           colorbar=False,
           #overlay=True,
           cmap='coolwarm', #"cold_hot",
           vmin=-0.5,
           vmax=0.5,
           )
